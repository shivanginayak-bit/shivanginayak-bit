# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanginayak-bit/shivanginayak-bit/blob/main/Snippets_Importing_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing a library that is not in Colaboratory
#
# To import a library that's not in Colaboratory by default, you can use `!pip install` or `!apt-get install`.

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %% [markdown]
# # Install 7zip reader [libarchive](https://pypi.python.org/pypi/libarchive)

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive
# Out:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 123105 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.4.0-2ubuntu1.2_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.4.0-2ubuntu1.2) ...
# Setting up libarchive-dev:amd64 (3.4.0-2ubuntu1.2) ...
# Processing triggers for man-db (2.9.1-1) ...
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 3.8 MB/s eta 0:00:00
# ...
#   Created wheel for libarchive: filename=libarchive-0.4.7-py3-none-any.whl size=31629 sha256=d75cbdd4fb4edaf94344d635cff6f9e8a8cbcce2559d686d31310f05d63e9d6f
#   Stored in directory: /root/.cache/pip/wheels/3a/94/d0/6cd83c8a80a4236fd4cb2a1fd846ecf72ab1e0ac238c5951c0
# Successfully built libarchive
# ...

# %% [markdown]
# # Install GraphViz & [PyDot](https://pypi.python.org/pypi/pydot)

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot

# %% [markdown]
# # Install [cartopy](http://scitools.org.uk/cartopy/docs/latest/)

# %%
# !pip install cartopy
import cartopy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 78.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.7 MB/s eta 0:00:00
# ...
#   Created wheel for cartopy: filename=Cartopy-0.21.1-cp310-cp310-linux_x86_64.whl size=11102766 sha256=e3a0e3fc288d7b7e7ac861e0f9329fdf3315849706c5f8dd9534724107dacb1f
#   Stored in directory: /root/.cache/pip/wheels/30/b0/1a/1c1909e00c76653dc4e2ff48555257c0eb2d1698280c8d9955
# Successfully built cartopy
# ...

# %%
pip install farm-haystack[inference]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.2/737.2 kB 19.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 93.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 82.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 94.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 28.7 MB/s eta 0:00:00
# ...

# %%
from haystack.nodes import FARMReader
reader= FARMReader(model_name_or_path='deepset/roberta-base-squad2',use_gpu=True)
data_dir='/content/CAR_OWNER_MANUAL'

# %%
import os

from haystack.agents import Agent, Tool
from haystack.agents.base import ToolsManager
from haystack.nodes import PromptNode, PromptTemplate
from haystack.nodes.retriever.web import WebRetriever
from haystack.pipelines import WebQAPipeline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 52.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 22.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 20.4 MB/s eta 0:00:00
# ...

# %%
import json

# %%
import os
import requests
import time
import datetime
API_KEY = 'shivangi.nayak170@gmail.com_8e3ee584c80af5bb5ce0de71c800f693ef65d4ede13aab63839cd7d343013ec70b66352d'
BASE_URL="https://api.pdf.co/v1"
SourceFile="/content/ilovepdf_merged.pdf"
Pages=""
DestinationFile="\\result.json"
Async=True

# %%
def main(args = None):
  uploadedFileUrl= uploadFile(Sourcefile)
  If (uploadedFileUrl =None):
    convertPdfToJson(uploadedFileUrl,Destinationfile)


def convertPdftoJson(uploadedfileUrl,destinationFile):
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────╮
# │   If (uploadedFileUrl =None):                                                                    │
# │                             ▲                                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# SyntaxError: invalid syntax

# %%
import requests
import base64

url = "https://app.nanonets.com/api/v2/OCR/FullText"

payload={'urls': ['MY_IMAGE_URL']}
files=[
  ('file',('data',open('/content/ilovepdf_merged.pdf','rb'),'application/pdf'))
]
headers = {}

response = requests.request("POST", url, headers=headers, data=payload, files=files, auth=requests.auth.HTTPBasicAuth('8e3ee584c80af5bb5ce0de71c800f693ef65d4ede13aab63839cd7d343013ec70b66352d', ''))

print(response.text)
# Out:
# {"message":"Unauthorized","code":401,"errors":[{"reason":"Api Key provided in request is invalid","message":"Add valid api key in request header as explained here: https://app.nanonets.com/documentation#authentication"}]}

# %%
from haystack.document_stores import InMemoryDocumentStore

document_store = InMemoryDocumentStore(use_bm25=True)
# Out:
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0

# %%
from haystack.utils import fetch_archive_from_http, convert_files_to_docs
doc_dir = "/content/ilovepdf_merged.pdf"
got_docs = convert_files_to_docs(dir_path=doc_dir, split_paragraphs=True)
document_store.delete_documents()
document_store.write_documents(got_docs)

# %%
from haystack.nodes import BM25Retriever, EmbeddingRetriever, FARMReader

bm25_retriever = BM25Retriever()

from haystack.pipelines import DocumentSearchPipeline
from haystack.utils import print_documents

p_retrieval = DocumentSearchPipeline(bm25_retriever)

# %%
from haystack.nodes import BM25Retriever, EmbeddingRetriever, FARMReader

# Initialize Sparse Retriever
bm25_retriever = BM25Retriever(document_store=document_store)

# Initialize embedding Retriever
embedding_retriever = EmbeddingRetriever(
    document_store=document_store, embedding_model="sentence-transformers/multi-qa-mpnet-base-dot-v1"
)
document_store.update_embeddings(embedding_retriever, update_existing_embeddings=False)

# Initialize Reader
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2")
# Out:
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
# INFO:haystack.nodes.retriever.dense:Init retriever using embeddings of model sentence-transformers/multi-qa-mpnet-base-dot-v1
# INFO:haystack.document_stores.memory:Updating embeddings for 0 docs ...
# Updating Embedding: 0 docs [00:00, ? docs/s]
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
# INFO:haystack.modeling.model.language_model: * LOADING MODEL: 'deepset/roberta-base-squad2' (Roberta)
# INFO:haystack.modeling.model.language_model:Auto-detected model language: english
# INFO:haystack.modeling.model.language_model:Loaded 'deepset/roberta-base-squad2' (Roberta model) from model hub.
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0

# %%
from haystack.pipelines import DocumentSearchPipeline
from haystack.utils import print_documents

p_retrieval = DocumentSearchPipeline(embedding_retriever)
res = p_retrieval.run(query="What is the top speed for mercedes-c-class-coupe-2020-november-c205?", params={"Retriever": {"top_k": 10}})
print_documents(res, max_text_len=200)
document_store.write_documents(res)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Query: What is the top speed for mercedes-c-class-coupe-2020-november-c205?
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 7>:7                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/haystack/document_stores/memory.py:185 in                │
# │ write_documents                                                                                  │
# │                                                                                                  │
# │    182 │   │   documents_objects = [                                                             │
# │    183 │   │   │   Document.from_dict(d, field_map=field_map) if isinstance(d, dict) else d for  │
# ...

# %%
from haystack.nodes import BM25Retriever

retriever = BM25Retriever(document_store)

# %%
from haystack.document_stores import InMemoryDocumentStore

document_store = InMemoryDocumentStore(use_bm25=True)
# Out:
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0

# %%
car_documents = retriever.retrieve(
    query="top speed",
    top_k=10,
    filters={"model": ["mercedes C class 2020 novemberc205", "mercedes C class 2020 may c205", "mercedes C classm 2021 January c205"]}
)
# Out:
# WARNING:haystack.document_stores.memory:InMemoryDocumentStore does not support filters for BM25 retrieval. This parameter is ignored.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/haystack/nodes/retriever/sparse.py:228 in retrieve       │
# │                                                                                                  │
# │   225 │   │   if all_terms_must_match is None:                                                   │
# │   226 │   │   │   all_terms_must_match = self.all_terms_must_match                               │
# │   227 │   │                                                                                      │
# ...

# %%
from haystack import Pipeline

pipeline = Pipeline()

# %%
pipeline.add_node(component=retriever, name='Retriever', inputs=['Query'])

# %%
from haystack.nodes import FARMReader

Reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True)
# Out:
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
# INFO:haystack.modeling.model.language_model: * LOADING MODEL: 'deepset/roberta-base-squad2' (Roberta)
# INFO:haystack.modeling.model.language_model:Auto-detected model language: english
# INFO:haystack.modeling.model.language_model:Loaded 'deepset/roberta-base-squad2' (Roberta model) from model hub.
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0

# %%
from haystack.pipelines import ExtractiveQAPipeline

pipe = ExtractiveQAPipeline(reader, retriever)

# %%
import logging

logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", level=logging.WARNING)
logging.getLogger("haystack").setLevel(logging.INFO)

# %%
prediction = pipe.run(
    query="What is the top speed of Mercedes C class?", params={"Retriever": {"top_k": 10}, "Reader": {"top_k": 5}}
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.10/dist-packages/haystack/pipelines/base.py:556 in run                    │
# │                                                                                                  │
# │    553 │   │   │   │   try:                                                                      │
# │    554 │   │   │   │   │   logger.debug("Running node '%s` with input: %s", node_id, node_input  │
# │    555 │   │   │   │   │   start = time()                                                        │
# │ ❱  556 │   │   │   │   │   node_output, stream_id = self._run_node(node_id, node_input)          │
# │    557 │   │   │   │   │   if "_debug" in node_output and node_id in node_output["_debug"]:      │
# │    558 │   │   │   │   │   │   node_output["_debug"][node_id]["exec_time_ms"] = round((time() -  │
# ...

# %%
from haystack.nodes import PreProcessor
from haystack.utils import convert_files_to_docs

# note that you can also use the document classifier before applying the PreProcessor, e.g. before splitting your documents
all_docs = convert_files_to_docs(dir_path=doc_dir)
preprocessor_sliding_window = PreProcessor(split_overlap=3, split_length=10, split_respect_sentence_boundary=False)
docs_sliding_window = preprocessor_sliding_window.process(all_docs)
# Out:
# Preprocessing: 0docs [00:00, ?docs/s]

# %%
es_retriever = BM25Retriever(document_store)
es_retriever.debug = True

# %%
class QueryClassifier(BaseComponent):
        outgoing_edges = 2

        def run(self, query):
            if "?" in query:
                return {}, "output_1"

            else:
                return {}, "output_2"

pipe = Pipeline()
pipe.add_node(component=QueryClassifier(), name="QueryClassifier", inputs=["Query"])
pipe.add_node(component=es_retriever, name="ESRetriever", inputs=["QueryClassifier.output_1"])
pipe.add_node(component=dpr_retriever, name="DPRRetriever", inputs=["QueryClassifier.output_2"])
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'BaseComponent' is not defined

# %%
 pipe.add_node(component=JoinDocuments(join_mode="concatenate"), name="JoinResults",
                  inputs=["ESRetriever", "DPRRetriever"])
 pipe.add_node(component=reader, name="QAReader", inputs=["JoinResults"])
 res = p.run(query="What did Einstein work on?", params={"ESRetriever": {"top_k": 1}, "DPRRetriever": {"top_k": 3}})

# %%
result = pipeline.run(
    query="What is the top speed for mercedes-c-class-coupe-2020-november-c205",
    params={
        "ESretriever": {
            "debug": True
        },
        "DPRRetriever": {
            "debug": True
        },
        "Reader": {
            "debug": True
        }
    }
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/haystack/pipelines/base.py:511 in run                    │
# │                                                                                                  │
# │    508 │   │   )                                                                                 │
# │    509 │   │                                                                                     │
# │    510 │   │   # validate the node names                                                         │
# │ ❱  511 │   │   self._validate_node_names_in_params(params=params)                                │
# ...

# %%
from haystack.utils import launch_es

launch_es()
# Out:
# WARNING:haystack.utils.doc_store:Tried to start Elasticsearch through Docker but this failed. It is likely that there is already an existing Elasticsearch instance running.

# %%
pip install farm-haystack[elasticsearch]

# %%
from haystack import Pipeline
# !pip install farm-haystack[pdf]
from haystack.nodes import PreProcessor

processor = PreProcessor(
    clean_empty_lines=True,
    clean_whitespace=True,
    clean_header_footer=True,
    split_by="word",
    split_length=200,
    split_respect_sentence_boundary=True,
    split_overlap=0
)

# %%
doc = converter.convert(file_path=file, meta=None)
docs = processor.process(doc)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'converter' is not defined

# %%
from haystack.pipelines import Pipeline
from haystack.nodes import PreProcessor, TextConverter, Retriever
from haystack.nodes import DeepsetCloudDocumentStore

pipeline = Pipeline()
pipeline.add_node(component=text_converter, name="TextConverter", inputs=["File"])
pipeline.add_node(component=preprocessor, name="PreProcessor", inputs=["TextConverter"])
pipeline.add_node(component=retriever, name="EmbeddingRetriever", inputs=["PreProcessor"])
pipeline.add_node(component=document_store, name="DeepsetCloudDocumentStore", inputs="EmbeddingRetriever"
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3553 in run_code        │
# │                                                                                                  │
# │   3550 │   │   │   │   elif async_ :                                                             │
# │   3551 │   │   │   │   │   await eval(code_obj, self.user_global_ns, self.user_ns)               │
# │   3552 │   │   │   │   else:                                                                     │
# │ ❱ 3553 │   │   │   │   │   exec(code_obj, self.user_global_ns, self.user_ns)                     │
# │   3554 │   │   │   finally:                                                                      │
# │   3555 │   │   │   │   # Reset our crash handler in place                                        │
# ...

# %%
pip install farm-haystack[elasticsearch]
from haystack.document_stores import ElasticsearchDocumentStore
from haystack.nodes import BM25Retriever
from haystack.pipelines import ExtractiveQAPipeline

document_store = ElasticsearchDocumentStore()
Retriever = BM25Retriever(document_store)
p = ExtractiveQAPipeline(reader, retriever)
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ pip install farm-haystack[elasticsearch]                                                         │
# │     ▲                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# SyntaxError: invalid syntax

# %%
import os
import time

from haystack.document_stores.elasticsearch import ElasticsearchDocumentStore

# %%
from haystack.pipelines import ExtractiveQAPipeline
from haystack.nodes import FARMReader, BM25Retriever


retriever = BM25Retriever(document_store=document_store)
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True)
pipe = ExtractiveQAPipeline(reader, retriever)
# Out:
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
# INFO:haystack.modeling.model.language_model: * LOADING MODEL: 'deepset/roberta-base-squad2' (Roberta)
# INFO:haystack.modeling.model.language_model:Auto-detected model language: english
# INFO:haystack.modeling.model.language_model:Loaded 'deepset/roberta-base-squad2' (Roberta model) from model hub.
# INFO:haystack.modeling.utils:Using devices: CPU - Number of GPUs: 0
